# %% [markdown]
# ## Comparison of binomial tree and 1D neural network

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from neural_network.trainer import GeneralTrainer
from neural_network.payoff import Put
from neural_network.config import MarketParams, ModelConfig

from black_scholes.tree import BinomialTree

from utility.plot import plot_price_heatmaps, plot_free_boundary
from utility.continuation_prob import compute_continuation_probs

# %%
S0 = 1.0
r = 0
sigma = 0.3
K = 1.0
T = 1.0
S_min = 0.0
S_max = 3 * K

market_params = MarketParams(n_assets=1, S0=S0, r=r, sigma=sigma, K=K, T=T, S_min=S_min, S_max=S_max)
exercise_type = "american"

# %%
bt = BinomialTree(market_params, exercise_type=exercise_type, n_steps=100)

# %%
input_size = 2
hidden_sizes = [32, 32, 32]
output_size = 1
activation = nn.Sigmoid()
learning_rate = 0.001
model_config = ModelConfig(
    input_size=input_size,
    hidden_sizes=hidden_sizes,
    output_size=output_size,
    activation=activation,
    learning_rate=learning_rate
)

# %%
put_payoff = Put()
trainer = GeneralTrainer(model_config, market_params, put_payoff, exercise_type=exercise_type, seed=12)

weights = {
    'pde': 5,
    'exercise': 5,
    'boundary_Smax': 3,
    'boundary_Smin': 3
}

trainer.set_loss_weights(weights)
trainer.train(batch_size=4000, epochs=20000, tol=1e-7)
# Out:
# Iteration 0	Training Loss: 0.15138491988182068	Validation Loss: 0.1505502462387085
# Iteration 100	Training Loss: 0.10122902691364288	Validation Loss: 0.10006721317768097
# Iteration 200	Training Loss: 0.010392909869551659	Validation Loss: 0.01009569875895977
# Iteration 300	Training Loss: 0.0024782842956483364	Validation Loss: 0.002459013368934393
# Iteration 400	Training Loss: 0.0014302441850304604	Validation Loss: 0.0013934365706518292
# Iteration 500	Training Loss: 0.0011878565419465303	Validation Loss: 0.0012116706930100918
# Iteration 600	Training Loss: 0.0011505766306072474	Validation Loss: 0.0011266916990280151
# Iteration 700	Training Loss: 0.0011374595342203975	Validation Loss: 0.0011215303093194962
# Iteration 800	Training Loss: 0.001117832027375698	Validation Loss: 0.0010770912049338222
# Iteration 900	Training Loss: 0.001062100986018777	Validation Loss: 0.0010475825984030962
# Iteration 1000	Training Loss: 0.001026232959702611	Validation Loss: 0.0010755877010524273
# Iteration 1100	Training Loss: 0.0010354981059208512	Validation Loss: 0.0010467824758961797
# Iteration 1200	Training Loss: 0.001047598896548152	Validation Loss: 0.00102712819352746
# Iteration 1300	Training Loss: 0.0010194368660449982	Validation Loss: 0.0010105278342962265
# Iteration 1400	Training Loss: 0.000995272072032094	Validation Loss: 0.0010102023370563984
# Iteration 1500	Training Loss: 0.0010048263939097524	Validation Loss: 0.0010090578580275178
# Iteration 1600	Training Loss: 0.0009780460968613625	Validation Loss: 0.0009816314559429884
# Iteration 1700	Training Loss: 0.0009787874296307564	Validation Loss: 0.0009855794487521052
# Iteration 1800	Training Loss: 0.0009666203986853361	Validation Loss: 0.0009700948721729219
# Iteration 1900	Training Loss: 0.0009484346373938024	Validation Loss: 0.0009623630903661251
# Iteration 2000	Training Loss: 0.0009522218606434762	Validation Loss: 0.0009682589443400502
# Iteration 19400	Training Loss: 0.0008828359423205256	Validation Loss: 0.0009260164806619287
# Iteration 19500	Training Loss: 0.0008805542020127177	Validation Loss: 0.0008963498985394835
# Iteration 19600	Training Loss: 0.000882862601429224	Validation Loss: 0.0009043375612236559
# Iteration 19700	Training Loss: 0.0008792972657829523	Validation Loss: 0.000907461391761899
# Iteration 19800	Training Loss: 0.0008977528195828199	Validation Loss: 0.0009115402936004102
# Iteration 19900	Training Loss: 0.0008786906255409122	Validation Loss: 0.0009078893344849348

# %%
trainer.plot_losses_detailed(start_epoch=100)

# %%
# grid resolution
num_S = 80
num_T = 80

Ss = np.linspace(S_min, S_max, num_S)
Ts = np.linspace(0, T-1e-4, num_T)  # avoid exactly zero maturity

nn_prices = np.zeros((num_T, num_S))
bt_prices = np.zeros((num_T, num_S))
intrinsics = np.zeros((num_T, num_S))

for i, t_val in enumerate(Ts):
    for j, s_val in enumerate(Ss):
        nn_prices[i, j] = trainer.predict(t_val, s_val).item()
        bt_prices[i, j] = bt.predict(t_val, s_val)
# Out:
# /var/folders/yc/lmxhkkxd611c8bx7dqjsmvr40000gn/T/ipykernel_24098/664654973.py:15: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   bt_prices[i, j] = bt.predict(t_val, s_val)

# %%
plot_price_heatmaps(
    prices1=nn_prices, prices2=bt_prices,
    xlabel='Underlying price S', ylabel='Time elapsed t',
    title1='Neural Network Prices', title2='Binomial Tree Prices', title_diff='Absolute Price Difference',
    label1='NN price', label2='BT price', label_diff='Absolute price difference',
    extent=[Ss[0], Ss[-1], Ts[0], Ts[-1]]
)

# %%
# Error at the money
S_try = K
nn_prices_atm = [trainer.predict(t, S_try).item() for t in Ts]
bt_prices_atm = [bt.predict(t, S_try) for t in Ts]

plt.figure(figsize=(8, 5))
plt.plot(Ts, nn_prices_atm, label='Neural Network Price at S=K')
plt.plot(Ts, bt_prices_atm, label='Binomial Tree Price at S=K')
plt.xlabel('Time elapsed t')
plt.ylabel('Option Price at S=K')
plt.title('Option Price at the Money (S=K) over Time')
plt.legend()
plt.show()

# %%
# Initial price
t_ind = 0
plt.plot(Ss, nn_prices[t_ind, :], label='NN price at maturity')
plt.plot(Ss, bt_prices[t_ind, :], label='Tree price at maturity')
# plt.plot(Ss, put_payoff.smoothed(torch.tensor(Ss), K, beta=50), label='Smoothed Payoff at maturity')
plt.xlabel('Underlying price S')
plt.ylabel('Price')
plt.title('Initial option price (t=0)')
plt.legend()
plt.show()

# %%
# Payoff price
t_ind = -1
plt.plot(Ss, nn_prices[t_ind, :], label='NN price at maturity')
plt.plot(Ss, bt_prices[t_ind, :], label='Tree price at maturity')
# plt.plot(Ss, put_payoff.smoothed(torch.tensor(Ss), K, beta=50), label='Smoothed Payoff at maturity')
plt.xlabel('Underlying price S')
plt.ylabel('Price')
plt.title('Option Price at Maturity (t=T)')
plt.legend()
plt.show()

# %%
# Payoff price
t_ind = -1
plt.plot(Ss, nn_prices[t_ind, :] - bt_prices[t_ind, :], label='Price difference at maturity')
plt.xlabel('Underlying price S')
plt.ylabel('Price')
plt.title('Price difference at Maturity (t=T)')
plt.legend()
plt.show()

# %% [markdown]
# ### Fine tune the network

# %%
# trainer.fine_tune(batch_size=1000, epochs=10000, tol=1e-2)

# %%
# # grid resolution
# num_S = 80
# num_T = 80

# Ss = np.linspace(S_min, S_max, num_S)
# Ts = np.linspace(0, T-1e-4, num_T)  # avoid exactly zero maturity

# nn_prices = np.zeros((num_T, num_S))
# bt_prices = np.zeros((num_T, num_S))

# for i, t_val in enumerate(Ts):
#     for j, s_val in enumerate(Ss):
#         nn_prices[i, j] = trainer.predict(t_val, s_val).item()
#         bt_prices[i, j] = bt.predict(t_val, s_val)

# %%
# plot_price_heatmaps(
#     prices1=nn_prices, prices2=bt_prices,
#     xlabel='Underlying price S', ylabel='Time elapsed t',
#     title1='Neural Network Prices (finetuned)', title2='Binomial Tree Prices', title_diff='Absolute Price Difference',
#     label1='NN price', label2='BT price', label_diff='Absolute price difference',
#     extent=[Ss[0], Ss[-1], Ts[0], Ts[-1]]
# )

# %% [markdown]
# ## Free boundary

# %%
# grid resolution
num_S = 200
num_T = 200

Ss = np.linspace(0.7, 1.1, num_S)
Ts = np.linspace(0, T-1e-4, num_T)  # avoid exactly zero maturity

nn_prices = np.zeros((num_T, num_S))
bt_prices = np.zeros((num_T, num_S))
intrinsics = np.zeros((num_T, num_S))

for i, t_val in enumerate(Ts):
    for j, s_val in enumerate(Ss):
        nn_prices[i, j] = trainer.predict(t_val, s_val).item()
        bt_prices[i, j] = bt.predict(t_val, s_val)
        intrinsics[i, j] = max(0, K - s_val)
# Out:
# /var/folders/yc/lmxhkkxd611c8bx7dqjsmvr40000gn/T/ipykernel_24098/3733979399.py:15: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   bt_prices[i, j] = bt.predict(t_val, s_val)

# %%
cont_probs_bt = compute_continuation_probs(bt_prices, intrinsics, eps1=1e-4, eps2=1e-1, one=0.99, shift=-1e-4)
cont_probs_nn = compute_continuation_probs(nn_prices, intrinsics, eps1=1e-2, eps2=2, one=0.99, shift=0)
# Out:
# /Users/jameswu/Documents/Imperial/Year 4/M4R/utility/continuation_prob.py:34: RuntimeWarning: divide by zero encountered in divide
#   d = (prices - intrinsics + shift) / intrinsics
# /Users/jameswu/Documents/Imperial/Year 4/M4R/utility/continuation_prob.py:6: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))

# %%
vmax = 1
vmin = 0

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
im = plt.imshow(cont_probs_bt, extent=[Ss[0], Ss[-1], Ts[0], Ts[-1]], aspect='auto', origin='lower', cmap='Grays', vmin=vmin, vmax=vmax)
plt.colorbar(im, label="Continuation Probability")
plt.xlabel("Underlying price S")
plt.ylabel("Time elapsed t")
plt.title("Continuation probabilities for Binomial Tree")


plt.subplot(1, 2, 2)
im = plt.imshow(cont_probs_nn, extent=[Ss[0], Ss[-1], Ts[0], Ts[-1]], aspect='auto', origin='lower', cmap='Grays', vmin=vmin, vmax=vmax)
plt.colorbar(im, label="Continuation Probability")
plt.xlabel("Underlying price S")
plt.ylabel("Time elapsed t")
plt.title("Continuation probabilities for Neural Network")

plt.tight_layout()
plt.show()
