# %%
import torch.nn as nn
import matplotlib.pyplot as plt

from black_scholes.pinn.bs_pinn import BlackScholesPINN
from utility.model import EarlyStopping
from config.bs_1d import *
from config.plot_settings import *

# %%
seeds = [65]
for seed in seeds:
    print("Training with seed:", seed)
    pinn = BlackScholesPINN(model_config, seed=seed)
    pinn.set_params(K, r, sigma, T, S_min, S_max)

    early_stopping = EarlyStopping(patience=500, min_delta=1e-7)
    pinn.train(batch_size=4096, epochs=30000, early_stopping=early_stopping, anneal_freq=50000, alpha=0.9)
    pinn.save(f'../../models/bs_pinn_1d/{seed}.pth')
# Out:
# Training with seed: 65
# Iter      0 | Train: 2.7050e-01 | Val: 1.0185e+00 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter    500 | Train: 3.3045e-03 | Val: 1.3172e-02 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   1000 | Train: 1.2271e-03 | Val: 4.8018e-03 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   1500 | Train: 7.0170e-04 | Val: 2.8555e-03 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   2000 | Train: 3.2599e-04 | Val: 1.3194e-03 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   2500 | Train: 1.5421e-04 | Val: 6.4024e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   3000 | Train: 8.3143e-05 | Val: 3.5370e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   3500 | Train: 6.8191e-05 | Val: 2.7795e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   4000 | Train: 5.5086e-05 | Val: 2.1748e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   4500 | Train: 5.0267e-05 | Val: 1.8243e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   5000 | Train: 4.2666e-05 | Val: 1.5501e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   5500 | Train: 3.3347e-05 | Val: 1.3320e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   6000 | Train: 3.0540e-05 | Val: 1.1721e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   6500 | Train: 2.6693e-05 | Val: 1.0863e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   7000 | Train: 2.7379e-05 | Val: 1.0140e-04 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   7500 | Train: 2.5040e-05 | Val: 9.4583e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   8000 | Train: 2.1696e-05 | Val: 8.7865e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   8500 | Train: 2.0137e-05 | Val: 8.2915e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   9000 | Train: 1.8414e-05 | Val: 7.7520e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter   9500 | Train: 1.8385e-05 | Val: 7.1862e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  10000 | Train: 1.7096e-05 | Val: 6.6614e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  10500 | Train: 1.6317e-05 | Val: 6.3129e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  11000 | Train: 1.4795e-05 | Val: 5.9656e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  11500 | Train: 1.4003e-05 | Val: 5.6325e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  12000 | Train: 1.3255e-05 | Val: 5.3317e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  12500 | Train: 1.2562e-05 | Val: 5.1247e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  13000 | Train: 1.2421e-05 | Val: 4.9153e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  13500 | Train: 1.1761e-05 | Val: 4.7357e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  14000 | Train: 1.1097e-05 | Val: 4.5525e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  14500 | Train: 1.1049e-05 | Val: 4.4370e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  15000 | Train: 1.0401e-05 | Val: 4.3310e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  15500 | Train: 1.0065e-05 | Val: 4.2191e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  16000 | Train: 1.0222e-05 | Val: 4.1284e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  16500 | Train: 9.6010e-06 | Val: 4.0596e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  17000 | Train: 9.5731e-06 | Val: 4.0054e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  17500 | Train: 9.4364e-06 | Val: 3.9393e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  18000 | Train: 9.7402e-06 | Val: 3.8833e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  18500 | Train: 9.3154e-06 | Val: 3.8460e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  19000 | Train: 9.6295e-06 | Val: 3.8100e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  19500 | Train: 8.4706e-06 | Val: 3.7765e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  20000 | Train: 9.0221e-06 | Val: 3.7424e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  20500 | Train: 8.7590e-06 | Val: 3.7131e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  21000 | Train: 9.5455e-06 | Val: 3.6922e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  21500 | Train: 9.0686e-06 | Val: 3.6660e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  22000 | Train: 9.0108e-06 | Val: 3.6405e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  22500 | Train: 8.6667e-06 | Val: 3.6266e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  23000 | Train: 7.8620e-06 | Val: 3.6092e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  23500 | Train: 9.3691e-06 | Val: 3.5917e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  24000 | Train: 9.1782e-06 | Val: 3.5772e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  24500 | Train: 9.2104e-06 | Val: 3.5640e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  25000 | Train: 8.9734e-06 | Val: 3.5523e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  25500 | Train: 8.0758e-06 | Val: 3.5413e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Iter  26000 | Train: 7.6485e-06 | Val: 3.5312e-05 | Weights: variational=0.250  terminal=0.250  Smin=0.250  Smax=0.250
# Early stopping at epoch 26312

# %%
plt.figure(figsize=figsize2)

plt.subplot(1, 2, 1)

start_epoch = 0
end_epoch = 500
detailed = True

x = range(start_epoch, end_epoch)
for key in pinn.history:
    if (key == 'loss') ^ (detailed):
        plt.plot(x, pinn.history[key][start_epoch:end_epoch], label=key)

plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title("Loss Components")
plt.legend()

plt.subplot(1, 2, 2)
start_epoch = 5000
end_epoch = len(pinn.history['loss'])
detailed = True
x = range(start_epoch, end_epoch)
for key in pinn.history:
    if (key == 'loss') ^ (detailed):
        plt.plot(x, pinn.history[key][start_epoch:end_epoch], label=key)

plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title("Loss Components")
plt.legend()

plt.tight_layout()

plt.savefig(f"../../plots/black_scholes/bs_1d_train_loss.png")
plt.show()

# %%
atm_prices = [pinn.atm_price[i] for i in range(len(pinn.atm_price))]

# %%
# True price benchmark
from black_scholes.tree.tree import BinomialTree
bt = BinomialTree(K, r, sigma, T, n_steps=1000)
true_atm_price = bt.predict(0, K)
print(true_atm_price)
# Out:
# [0.08336577]

# %%
plt.figure(figsize=figsize1)
plt.plot(atm_prices, label='PINN Price')
plt.axhline(true_atm_price, color=CRIMSON, linestyle='--', label='Tree Price')
plt.xlabel('Epoch')
plt.ylabel('Price f(0, K)')
plt.title("At-the-money Price Convergence")
plt.legend()
plt.savefig(f"../../plots/black_scholes/bs_1d_train_atm_price.png")
plt.show()
