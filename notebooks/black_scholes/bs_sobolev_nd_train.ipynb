# %%
import torch.nn as nn

from black_scholes.sobolev.bs_sobolev_nd import BlackScholesSobolevMultiAsset
from utility.model import EarlyStopping, ModelConfig
from config.bs_nd import *

# %%
seeds = [0]
for seed in seeds:
    print(f'Training model with seed {seed}...')
    model = BlackScholesSobolevMultiAsset(model_config, seed=seed)
    model.set_params(K, r, sigmas, corr, T, S_mins, S_maxs)

    early_stopping = EarlyStopping(patience=500, min_delta=1e-7)
    model.train(batch_size=4096, epochs=30000, early_stopping=early_stopping, anneal_freq=50000, alpha=0.9)
    model.save(f'../../models/bs_sobolev_nd/{seed}.pth')
# Out:
# Training model with seed 0...
# Iter      0 | Train: 1.6428e+00 | Val: 6.1668e+00 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter    500 | Train: 9.8196e-02 | Val: 3.8755e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1000 | Train: 3.6230e-02 | Val: 9.8156e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1500 | Train: 1.8360e-02 | Val: 5.6504e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2000 | Train: 8.9193e-03 | Val: 4.4742e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2500 | Train: 8.5789e-03 | Val: 3.9910e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   3000 | Train: 7.6509e-03 | Val: 3.5431e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   3500 | Train: 7.0499e-03 | Val: 3.3482e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   4000 | Train: 5.6690e-03 | Val: 2.8729e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   4500 | Train: 4.1214e-03 | Val: 2.8579e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   5000 | Train: 5.8200e-03 | Val: 2.6799e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   5500 | Train: 5.8323e-03 | Val: 2.6442e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   6000 | Train: 5.2089e-03 | Val: 2.4670e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   6500 | Train: 4.8339e-03 | Val: 2.4316e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   7000 | Train: 4.5245e-03 | Val: 2.7875e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   7500 | Train: 6.5395e-03 | Val: 2.3412e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   8000 | Train: 4.6826e-03 | Val: 2.1873e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   8500 | Train: 5.5967e-03 | Val: 2.1217e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   9000 | Train: 4.9653e-03 | Val: 2.2630e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   9500 | Train: 5.5828e-03 | Val: 2.1598e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  10000 | Train: 4.4725e-03 | Val: 2.1129e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  10500 | Train: 5.3370e-03 | Val: 1.9449e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  11000 | Train: 4.6031e-03 | Val: 1.8944e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  11500 | Train: 4.6785e-03 | Val: 1.9800e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  12000 | Train: 4.1396e-03 | Val: 2.0613e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Early stopping at epoch 12312
