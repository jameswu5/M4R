# %%
import torch.nn as nn

from black_scholes.sobolev.bs_sobolev_nd import BlackScholesSobolevMultiAsset
from utility.model import EarlyStopping, ModelConfig
from config.bs_nd import *

# %%
seeds = range(1, 4)
for seed in seeds:
    print(f'Training model with seed {seed}...')
    model = BlackScholesSobolevMultiAsset(model_config, seed=seed)
    model.set_params(K, r, sigmas, corr, T, S_mins, S_maxs)

    early_stopping = EarlyStopping(patience=1000, min_delta=1e-6)
    model.train(batch_size=4096, epochs=30000, early_stopping=early_stopping, anneal_freq=1000, alpha=0.9)
    model.save(f'../../models/bs_sobolev_nd/{seed}.pth')
# Out:
# Training model with seed 1...
# Iter      0 | Train: 2.8558e+00 | Val: 1.1078e+01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter    500 | Train: 2.6149e-01 | Val: 8.0972e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1000 | Train: 1.3918e-01 | Val: 1.7466e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1500 | Train: 7.8196e-02 | Val: 1.2997e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2000 | Train: 4.6433e-02 | Val: 1.1852e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2500 | Train: 1.1311e-01 | Val: 1.0914e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   3000 | Train: 1.9451e-02 | Val: 9.6763e-02 | Weights: pde=0.400  J2=0.089  J3=0.008  J4=0.504
# Iter   3500 | Train: 6.4764e-02 | Val: 1.0461e-01 | Weights: pde=0.400  J2=0.089  J3=0.008  J4=0.504
# Iter   4000 | Train: 5.1865e-02 | Val: 1.2153e-01 | Weights: pde=0.531  J2=0.187  J3=0.144  J4=0.139
# Early stopping at epoch 4021
# Training model with seed 2...
# Iter      0 | Train: 5.7328e+00 | Val: 1.1519e+01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter    500 | Train: 2.5451e-01 | Val: 8.0131e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1000 | Train: 7.6238e-02 | Val: 2.7087e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1500 | Train: 8.1873e-02 | Val: 1.8304e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2000 | Train: 1.0494e-01 | Val: 2.0665e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2500 | Train: 4.1697e-02 | Val: 1.6433e-01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   3000 | Train: 1.6551e-02 | Val: 1.1574e-01 | Weights: pde=0.265  J2=0.269  J3=0.016  J4=0.450
# Iter   3500 | Train: 1.6191e-02 | Val: 9.7509e-02 | Weights: pde=0.265  J2=0.269  J3=0.016  J4=0.450
# Iter   4000 | Train: 3.3147e-02 | Val: 9.2102e-02 | Weights: pde=0.329  J2=0.092  J3=0.532  J4=0.047
# Iter   4500 | Train: 4.1526e-02 | Val: 1.0186e-01 | Weights: pde=0.329  J2=0.092  J3=0.532  J4=0.047
# Iter   5000 | Train: 1.3985e-02 | Val: 9.2095e-02 | Weights: pde=0.083  J2=0.260  J3=0.010  J4=0.647
# Iter   5500 | Train: 1.4884e-02 | Val: 8.2372e-02 | Weights: pde=0.083  J2=0.260  J3=0.010  J4=0.647
# Iter   6000 | Train: 4.2616e-02 | Val: 8.1151e-02 | Weights: pde=0.186  J2=0.096  J3=0.603  J4=0.115
# Iter   6500 | Train: 1.6756e-01 | Val: 1.1547e-01 | Weights: pde=0.186  J2=0.096  J3=0.603  J4=0.115
# Early stopping at epoch 6978
# Training model with seed 3...
# Iter      0 | Train: 2.6602e+00 | Val: 1.5369e+01 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter    500 | Train: 1.9496e-01 | Val: 4.0882e+00 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1000 | Train: 1.6728e-01 | Val: 3.0044e+00 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1500 | Train: 9.4038e-02 | Val: 2.2969e+00 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2000 | Train: 4.0390e-02 | Val: 1.8889e+00 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2500 | Train: 3.5714e-02 | Val: 1.6630e+00 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   3000 | Train: 1.1146e-02 | Val: 1.6463e+00 | Weights: pde=0.354  J2=0.038  J3=0.034  J4=0.574
# Iter   3500 | Train: 1.9515e-02 | Val: 1.6675e+00 | Weights: pde=0.354  J2=0.038  J3=0.034  J4=0.574
# Early stopping at epoch 3698
