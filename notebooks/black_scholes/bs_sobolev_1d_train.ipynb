# %%
import torch.nn as nn

from black_scholes.sobolev.bs_sobolev import BlackScholesSobolev
from utility.model import EarlyStopping, ModelConfig
from config.bs_1d import *

# %%
seeds = [10]
for seed in seeds:
    print("Training with seed:", seed)
    model = BlackScholesSobolev(model_config, seed=seed)
    model.set_params(K, r, sigma, T, S_min, S_max)

    early_stopping = EarlyStopping(patience=500, min_delta=1e-7)
    model.train(batch_size=4096, epochs=30000, early_stopping=early_stopping, anneal_freq=50000, alpha=0.9)
    model.save(f'../../models/bs_sobolev_1d/{seed}.pth')
# Out:
# Training with seed: 10
# Iter      0 | Train: 3.6768e-01 | Val: 1.4488e+00 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter    500 | Train: 1.9082e-02 | Val: 7.7644e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1000 | Train: 9.2204e-03 | Val: 3.8423e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   1500 | Train: 2.6600e-03 | Val: 1.1023e-02 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2000 | Train: 1.8090e-03 | Val: 7.0150e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   2500 | Train: 1.3975e-03 | Val: 5.7527e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   3000 | Train: 1.1406e-03 | Val: 4.9908e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   3500 | Train: 1.2305e-03 | Val: 4.5355e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   4000 | Train: 9.6261e-04 | Val: 4.0104e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   4500 | Train: 9.8717e-04 | Val: 3.6946e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   5000 | Train: 8.4851e-04 | Val: 3.4365e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   5500 | Train: 9.1670e-04 | Val: 3.3377e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   6000 | Train: 6.3605e-04 | Val: 3.2011e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   6500 | Train: 6.7377e-04 | Val: 3.1583e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   7000 | Train: 6.3668e-04 | Val: 3.1061e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   7500 | Train: 6.1816e-04 | Val: 3.0163e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   8000 | Train: 7.2718e-04 | Val: 2.9683e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   8500 | Train: 6.8069e-04 | Val: 2.9770e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   9000 | Train: 8.9215e-04 | Val: 2.9297e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter   9500 | Train: 8.5185e-04 | Val: 2.9035e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  10000 | Train: 6.4457e-04 | Val: 2.8652e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  10500 | Train: 8.0537e-04 | Val: 2.8711e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  11000 | Train: 7.8303e-04 | Val: 2.8445e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  11500 | Train: 8.1243e-04 | Val: 2.8506e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  12000 | Train: 7.5528e-04 | Val: 2.8361e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  12500 | Train: 6.8124e-04 | Val: 2.7955e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  13000 | Train: 5.9485e-04 | Val: 2.7924e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  13500 | Train: 6.3939e-04 | Val: 2.7886e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  14000 | Train: 5.7427e-04 | Val: 2.7545e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  14500 | Train: 8.6364e-04 | Val: 2.7468e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  15000 | Train: 7.0421e-04 | Val: 2.7609e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  15500 | Train: 7.4475e-04 | Val: 2.7671e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  16000 | Train: 7.2863e-04 | Val: 2.7266e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  16500 | Train: 5.9547e-04 | Val: 2.7391e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  17000 | Train: 6.4229e-04 | Val: 2.7384e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  17500 | Train: 6.2737e-04 | Val: 2.7182e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  18000 | Train: 7.1043e-04 | Val: 2.7131e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  18500 | Train: 6.3230e-04 | Val: 2.7269e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  19000 | Train: 5.8373e-04 | Val: 2.6957e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  19500 | Train: 6.0933e-04 | Val: 2.7005e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Iter  20000 | Train: 5.1176e-04 | Val: 2.6864e-03 | Weights: pde=0.250  J2=0.250  J3=0.250  J4=0.250
# Early stopping at epoch 20321
